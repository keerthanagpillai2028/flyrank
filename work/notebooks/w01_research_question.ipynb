# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/keerthanagpillai2028/flyrank/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*
#
# I chose this lane because I want to identify which pages should be reviewed first for actions such as refreshing, expanding, protecting, pruning, or monitoring. This connects well with the starter dataset because it contains search visibility, traffic, content age, freshness, and trend signals. My goal is to use these observable signals to build an evidence-based ranking that helps prioritize pages for human review, rather than assuming that a model can guarantee which pages will improve.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*
#
# The decision is to prioritize pages for human review based on observable search and content signals. A content or SEO reviewer can then decide whether a page should be refreshed, expanded, protected, pruned, or monitored. A wrong recommendation could waste the review team's time or cause a useful page to be overlooked, so the ranking should be treated as decision support rather than a guarantee.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*
#
# The starter dataset contains 30,000 pages, and all 30,000 pages have recorded impressions. Among these pages, 16,262 are marked as declining based on the starter trend label. This suggests that there is a substantial set of pages that could be investigated and prioritized for review. These numbers make refresh and content opportunity scoring worth exploring, while the declining label should be treated as a starting proxy rather than proof that a page needs a refresh.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd

url = "https://raw.githubusercontent.com/flyrank-bih/flyrank-ml-internship-starter/main/data/raw/content_refresh_anonymized.csv"

df = pd.read_csv(url)

print("Total pages:", len(df))
print("Pages with impressions:", (df["impressions_90d"] > 0).sum())
print("Declining pages:", (df["trend_direction"] == "down").sum())
# Out:
# Total pages: 30000
# Pages with impressions: 30000
# Declining pages: 16262

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*
#
# What I can claim: I can identify observed patterns in the available search and content data and build a directional ranking of pages that may be worth reviewing. The result can be used as decision support to help prioritize limited review effort.
#
# What I cannot claim: I cannot prove that a particular content change will cause a page to recover, predict Google's ranking decisions, or guarantee that a highly ranked page is the best page to refresh.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
