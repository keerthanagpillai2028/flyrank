# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/keerthanagpillai2028/flyrank/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*
# I will treat refresh and content opportunity scoring as a ranking problem. The goal is to rank pages from higher to lower review priority using observable search, traffic, content, and trend signals. This fits the real decision because a reviewer has limited time and needs to know which pages should be reviewed first, rather than making the same yes/no decision for every page.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*
#
# For the starter task, I will use trend_direction == "down" as a proxy for a page that may need review. This label comes from an observed trend in the current data window, so it is not a future outcome and does not prove that a page needs a refresh. A stronger future version of the task could define a future decline or recovery outcome using separate feature and target windows.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*
#
# I will use Precision@50 because the output is a ranked review queue and a reviewer has limited capacity. A higher Precision@50 means that more of the pages ranked in the top 50 match the defined positive proxy. This metric directly reflects whether the ranking is useful for prioritizing pages for human review.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*
#
# One row represents one content page. Each page has observed search, traffic, content, and trend-related measurements. The ranking will compare these pages and assign them a review priority.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

import pandas as pd

url = "https://raw.githubusercontent.com/flyrank-bih/flyrank-ml-internship-starter/main/data/raw/content_refresh_anonymized.csv"

df = pd.read_csv(url)

df[[
    "content_id",
    "impressions_90d",
    "sessions_90d",
    "content_age_days",
    "trend_direction"
]].head()
# Out:
#              content_id  impressions_90d  sessions_90d  content_age_days  \
# 0  content_304f48230142             3803            17               187
# 1  content_a1fb4e703a9e            15320             9               445
# 2  content_9aa793d4d895            12581            11               141
# 3  content_331d6c4de07b            11751            78               463
# 4  content_d99b7a2d90ca            19140           145               263
#
#   trend_direction
# 0            down
# 1            down
# 2            down
# 3          stable
# 4            down

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*
#
# A fixed rule can identify obvious cases, but page-review priority depends on multiple signals that can interact in different ways. For example, a declining page with high impressions may deserve more attention than a declining page with very little exposure. ML can learn patterns across several observable signals and produce a ranked list that may prioritize pages more effectively than one manually chosen rule. The ML result should still be compared with a transparent baseline and used as decision support.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
